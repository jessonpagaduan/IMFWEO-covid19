# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.style.use('ggplot')

# %%
url1 = 'https://raw.githubusercontent.com/jessonpagaduan/IMFWEO-covid19/master/weo_june2020.csv'
df1 = pd.read_csv(url1, index_col=0)
df1
# Out:
#                 gdp_2018  gdp_2019  gdp_2020  gdp_2021  fch_gdp_2020  \
# Argentina           -2.5      -2.2      -9.9       3.9          -4.2
# Australia            2.8       1.8      -4.5       4.0           2.2
# Brazil               1.3       1.1      -9.1       3.6          -3.8
# Canada               2.0       1.7      -8.4       4.9          -2.2
# China                6.7       6.1       1.0       8.2          -0.2
# Egypt                5.3       5.6       2.0       2.0           0.0
# France               1.8       1.5     -12.5       7.3          -5.3
# Germany              1.5       0.6      -7.8       5.4          -0.8
# India                6.1       4.2      -4.5       6.0          -6.4
# Indonesia            5.2       5.0      -0.3       6.1          -0.8
# Iran                -5.4      -7.6      -6.0       3.1           0.0
# Italy                0.8       0.3     -12.8       6.3          -3.7
# Japan                0.3       0.7      -5.8       2.4          -0.6
# ...

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15, 10), sharey=True, sharex=True)

ax1 = df1[['fch_gdp_2020', 'fch_gdp_2021']].plot(kind='barh', ax=axs[0], legend=False)
ax1.invert_yaxis()
ax1.set(title='GDP growth (% change)', xlabel='Percentage points')

ax1 = df1[['fch_fb_2020', 'fch_fb_2021']].plot(kind='barh', ax=axs[1], legend=False)
ax1.invert_yaxis()
ax1.set(title='Fiscal balance (% of GDP)', xlabel='Percentage points')

ax1 = df1[['fch_gd_2020', 'fch_gd_2021']].plot(kind='barh', ax=axs[2], legend=False)
ax1.invert_yaxis()
ax1.set(title='Gross debt (% of GDP)', xlabel='Percentage points')
# Out:
# [Text(0.5, 0, 'Percentage points'), Text(0.5, 1.0, 'Gross debt (% of GDP)')]

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15, 10), sharey=True)

ax1 = df1['fch_gdp_2020'].plot(kind='barh', ax=axs[0], legend=False)
ax1.invert_yaxis()
ax1.set(title='GDP growth (% change)', xlabel='Percentage points')

ax1 = df1['fch_fb_2020'].plot(kind='barh', ax=axs[1], legend=False)
ax1.invert_yaxis()
ax1.set(title='Fiscal balance (% of GDP)', xlabel='Percentage points')

ax1 = df1['fch_gd_2020'].plot(kind='barh', ax=axs[2], legend=False)
ax1.invert_yaxis()
ax1.set(title='Gross debt (% of GDP)', xlabel='Percentage points')

fig.subplots_adjust(wspace=0.1)

plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15, 10), sharey=True)

ax1 = df1['fch_gdp_2020'].plot(kind='barh', ax=axs[0], legend=False)
ax1.invert_yaxis()
ax1.set(title='GDP growth (% change)', xlabel='Percentage points', xlim=(-7, 7))

ax1 = df1['fch_fb_2020'].plot(kind='barh', ax=axs[1], legend=False)
ax1.invert_yaxis()
ax1.set(title='Fiscal balance (% of GDP)', xlabel='Percentage points', xlim=(-11, 11))

ax1 = df1['fch_gd_2020'].plot(kind='barh', ax=axs[2], legend=False)
ax1.invert_yaxis()
ax1.set(title='Gross debt (% of GDP)', xlabel='Percentage points', xlim=(-16, 16))

fig.subplots_adjust(wspace=0.1)

plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15, 8), sharey=True)


color1 = []
for country in df1.dropna()['fch_gdp_2020'].index:
    if country == 'Australia':
        color1.append('gray')
    else:
        color1.append('red')
ax1 = df1.dropna()['fch_gdp_2020'].plot(kind='barh', color=color1, ax=axs[0], legend=False)
ax1.invert_yaxis()
ax1.set(xlabel='Percentage points', xlim=(-7, 7))
ax1.set_title('Change in projections of \nGDP growth as % change y-o-y ', fontsize=12)

color2 = []
for country in df1.dropna()['fch_fb_2020'].index:
    if country in ['Australia', 'Saudi Arabia']:
        color2.append('gray')
    else:
        color2.append('red')
ax2 = df1.dropna()['fch_fb_2020'].plot(kind='barh', color=color2, ax=axs[1], legend=False)
ax2.invert_yaxis()
ax2.set(xlabel='Percentage points', xlim=(-9, 9))
ax2.set_title('Change in projections of \nfiscal balance as % of GDP', fontsize=12)

color3 = []
for country in df1.dropna()['fch_gd_2020'].index:
    if country in ['Australia', 'Canada', 'China']:
        color3.append('gray')
    else:
        color3.append('red')
ax3 = df1.dropna()['fch_gd_2020'].plot(kind='barh', color=color3, ax=axs[2], legend=False)
ax3.invert_yaxis()
ax3.set(xlabel='Percentage points', xlim=(-17, 17))
ax3.set_title('Change in projections of \ngross debt as % of GDP', fontsize=12)

fig.suptitle('Prospects for a V-shaped recovery look unlikely as the global economic outlook for 2020 \
appears grim \nwith sizeable downward revisions in GDP growth projections, \
larger expected fiscal deficits, and elevated debt forecasts.', y=1.03, fontsize=15)
fig.subplots_adjust(wspace=0.05)

plt.annotate('Source: IMF World Economic Outlook database (accessed 13 July 2020).', 
             xy=(-2.4, -0.1), xycoords='axes fraction', textcoords='offset points', va='top')
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:43: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.

# %%
df1.dropna()['fch_gdp_2020'].index
# Out:
# Index(['Australia', 'Brazil', 'Canada', 'China', 'France', 'Germany', 'India',
#        'Indonesia', 'Italy', 'Japan', 'Korea', 'Mexico', 'Nigeria', 'Russia',
#        'Saudi Arabia', 'South Africa', 'Spain', 'Turkey', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df1
# Out:
#                 gdp_2018  gdp_2019  gdp_2020  gdp_2021  fch_gdp_2020  \
# Argentina           -2.5      -2.2      -9.9       3.9          -4.2
# Australia            2.8       1.8      -4.5       4.0           2.2
# Brazil               1.3       1.1      -9.1       3.6          -3.8
# Canada               2.0       1.7      -8.4       4.9          -2.2
# China                6.7       6.1       1.0       8.2          -0.2
# Egypt                5.3       5.6       2.0       2.0           0.0
# France               1.8       1.5     -12.5       7.3          -5.3
# Germany              1.5       0.6      -7.8       5.4          -0.8
# India                6.1       4.2      -4.5       6.0          -6.4
# Indonesia            5.2       5.0      -0.3       6.1          -0.8
# Iran                -5.4      -7.6      -6.0       3.1           0.0
# Italy                0.8       0.3     -12.8       6.3          -3.7
# Japan                0.3       0.7      -5.8       2.4          -0.6
# ...

# %%
df1 = df1.assign(gdp_2020_april = lambda x: x.gdp_2020 - x.fch_gdp_2020)
df1 = df1.assign(fb_2020_april = lambda x: x.fb_2020 - x.fch_fb_2020)
df1 = df1.assign(gd_2020_april = lambda x: x.gd_2020 - x.fch_gd_2020)

# %%
df1
# Out:
#                 gdp_2018  gdp_2019  gdp_2020  gdp_2021  fch_gdp_2020  \
# Argentina           -2.5      -2.2      -9.9       3.9          -4.2
# Australia            2.8       1.8      -4.5       4.0           2.2
# Brazil               1.3       1.1      -9.1       3.6          -3.8
# Canada               2.0       1.7      -8.4       4.9          -2.2
# China                6.7       6.1       1.0       8.2          -0.2
# Egypt                5.3       5.6       2.0       2.0           0.0
# France               1.8       1.5     -12.5       7.3          -5.3
# Germany              1.5       0.6      -7.8       5.4          -0.8
# India                6.1       4.2      -4.5       6.0          -6.4
# Indonesia            5.2       5.0      -0.3       6.1          -0.8
# Iran                -5.4      -7.6      -6.0       3.1           0.0
# Italy                0.8       0.3     -12.8       6.3          -3.7
# Japan                0.3       0.7      -5.8       2.4          -0.6
# ...

# %%
df1.dropna()
# Out:
#                 gdp_2018  gdp_2019  gdp_2020  gdp_2021  fch_gdp_2020  \
# Australia            2.8       1.8      -4.5       4.0           2.2
# Brazil               1.3       1.1      -9.1       3.6          -3.8
# Canada               2.0       1.7      -8.4       4.9          -2.2
# China                6.7       6.1       1.0       8.2          -0.2
# France               1.8       1.5     -12.5       7.3          -5.3
# Germany              1.5       0.6      -7.8       5.4          -0.8
# India                6.1       4.2      -4.5       6.0          -6.4
# Indonesia            5.2       5.0      -0.3       6.1          -0.8
# Italy                0.8       0.3     -12.8       6.3          -3.7
# Japan                0.3       0.7      -5.8       2.4          -0.6
# Korea                2.9       2.0      -2.1       3.0          -0.9
# Mexico               2.2      -0.3     -10.5       3.3          -3.9
# Nigeria              1.9       2.2      -5.4       2.6          -2.0
# ...

# %%
fig, ax = plt.subplots()
ax1 = sns.scatterplot(x=df1.dropna()['fb_2020_april'], y=df1.dropna()['gd_2020_april'],
                label='2020 projections in April')
ax2 = sns.scatterplot(x=df1.dropna()['fb_2020'], y=df1.dropna()['gd_2020'],
                label='2020 projections in June')
ax.set(ylabel='Gross debt (% of GDP)', xlabel='Fiscal balance (% of GDP)', 
       xlim=(-25, 0), ylim=(0, 300))
ax.legend(loc='upper left', frameon=True)
plt.show()

# %%
df2 = df1.dropna().assign(economy_type = 1)

# %%
advanced = df2.index.isin(['United States', 'Germany', 'France', 'Italy', 'Spain', 'Japan',
                          'United Kingdom', 'Canada', 'Australia', 'Korea'])

# %%
df2.rename(columns={'economy_type':'advanced'}, inplace=True)

# %%
df2.loc[['United States', 'Germany', 'France', 'Italy', 'Spain', 'Japan',
                          'United Kingdom', 'Canada', 'Australia', 'Korea'], 'advanced'] = 1

# %%
df2.loc[['Brazil', 'China', 'India', 'Indonesia', 'Mexico', 'Nigeria', 'Russia',
         'Saudi Arabia', 'South Africa', 'Turkey'], 'advanced'] = 0

# %%
df2
# Out:
#                 gdp_2018  gdp_2019  gdp_2020  gdp_2021  fch_gdp_2020  \
# Australia            2.8       1.8      -4.5       4.0           2.2
# Brazil               1.3       1.1      -9.1       3.6          -3.8
# Canada               2.0       1.7      -8.4       4.9          -2.2
# China                6.7       6.1       1.0       8.2          -0.2
# France               1.8       1.5     -12.5       7.3          -5.3
# Germany              1.5       0.6      -7.8       5.4          -0.8
# India                6.1       4.2      -4.5       6.0          -6.4
# Indonesia            5.2       5.0      -0.3       6.1          -0.8
# Italy                0.8       0.3     -12.8       6.3          -3.7
# Japan                0.3       0.7      -5.8       2.4          -0.6
# Korea                2.9       2.0      -2.1       3.0          -0.9
# Mexico               2.2      -0.3     -10.5       3.3          -3.9
# Nigeria              1.9       2.2      -5.4       2.6          -2.0
# ...

# %%
df2[advanced]
# Out:
#                 gdp_2018  gdp_2019  gdp_2020  gdp_2021  fch_gdp_2020  \
# Australia            2.8       1.8      -4.5       4.0           2.2
# Canada               2.0       1.7      -8.4       4.9          -2.2
# France               1.8       1.5     -12.5       7.3          -5.3
# Germany              1.5       0.6      -7.8       5.4          -0.8
# Italy                0.8       0.3     -12.8       6.3          -3.7
# Japan                0.3       0.7      -5.8       2.4          -0.6
# Korea                2.9       2.0      -2.1       3.0          -0.9
# Spain                2.4       2.0     -12.8       6.3          -4.8
# United Kingdom       1.3       1.4     -10.2       6.3          -3.7
# United States        2.9       2.3      -8.0       4.5          -2.1
#
#                 fch_gdp_2021  fb_2018  fb_2019  fb_2020  fb_2021  ...  \
# Australia               -2.1     -1.2     -3.9     -8.6     -8.4  ...
# ...

# %%
df2
# Out:
#                 gdp_2018  gdp_2019  gdp_2020  gdp_2021  fch_gdp_2020  \
# Australia            2.8       1.8      -4.5       4.0           2.2
# Brazil               1.3       1.1      -9.1       3.6          -3.8
# Canada               2.0       1.7      -8.4       4.9          -2.2
# China                6.7       6.1       1.0       8.2          -0.2
# France               1.8       1.5     -12.5       7.3          -5.3
# Germany              1.5       0.6      -7.8       5.4          -0.8
# India                6.1       4.2      -4.5       6.0          -6.4
# Indonesia            5.2       5.0      -0.3       6.1          -0.8
# Italy                0.8       0.3     -12.8       6.3          -3.7
# Japan                0.3       0.7      -5.8       2.4          -0.6
# Korea                2.9       2.0      -2.1       3.0          -0.9
# Mexico               2.2      -0.3     -10.5       3.3          -3.9
# Nigeria              1.9       2.2      -5.4       2.6          -2.0
# ...

# %%
fig, ax = plt.subplots()
ax1 = sns.scatterplot(x=df2['fb_2020_april'], y=df2['gd_2020_april'],
                      style=df2['advanced'], label='2020 projections in April')
ax2 = sns.scatterplot(x=df2['fb_2020'], y=df2['gd_2020'],
                      style=df2['advanced'], label='2020 projections in June')
ax.set(ylabel='Gross debt (% of GDP)', xlabel='Fiscal balance (% of GDP)', 
       xlim=(-25, 0), ylim=(0, 300))
ax.get_legend().remove()
plt.show()

# %%
df3 = pd.read_csv('imf-weo_jun_vs_apr.csv', index_col=0)

# %%
df3
# Out:
#                economy_type projections  forecast_date  gdp  fch_gdp  \
# Argentina          Emerging       April           2020 -5.7      NaN
# Australia          Advanced       April           2020 -6.7      NaN
# Brazil             Emerging       April           2020 -5.3      NaN
# Canada             Advanced       April           2020 -6.2      NaN
# China              Emerging       April           2020  1.2      NaN
# ...                     ...         ...            ...  ...      ...
# Spain              Advanced        June           2021  6.3      2.0
# Thailand           Emerging        June           2021  5.0     -1.1
# Turkey             Emerging        June           2021  5.0      0.0
# United Kingdom     Advanced        June           2021  6.3      2.3
# United States      Advanced        June           2021  4.5     -0.2
#
#                 fiscal_bal  fch_fiscal_bal  gross_debt  fch_gross_debt
# ...

# %%
scatter_data = df3.loc[:, ['economy_type', 'projections', 'forecast_date', 
                           'fiscal_bal', 'gross_debt']].dropna()

# %%
scatter_data
# Out:
#                economy_type projections  forecast_date  fiscal_bal  gross_debt
# Argentina          Emerging       April           2020         0.0         0.0
# Australia          Advanced       April           2020        -9.7        59.3
# Brazil             Emerging       April           2020        -9.4        98.2
# Canada             Advanced       April           2020       -11.8       109.6
# China              Emerging       April           2020       -11.2        64.9
# ...                     ...         ...            ...         ...         ...
# South Africa       Emerging        June           2021       -11.0        84.6
# Spain              Advanced        June           2021        -8.3       124.1
# Turkey             Emerging        June           2021        -7.5        42.2
# United Kingdom     Advanced        June           2021        -6.7       100.5
# United States      Advanced        June           2021       -12.4       146.1
#
# [100 rows x 5 columns]

# %%
data_2020 = scatter_data[scatter_data['forecast_date'] == 2020]

# %%
data_2020
# Out:
#                economy_type projections  forecast_date  fiscal_bal  gross_debt
# Argentina          Emerging       April           2020         0.0         0.0
# Australia          Advanced       April           2020        -9.7        59.3
# Brazil             Emerging       April           2020        -9.4        98.2
# Canada             Advanced       April           2020       -11.8       109.6
# China              Emerging       April           2020       -11.2        64.9
# Egypt              Emerging       April           2020         0.0         0.0
# France             Advanced       April           2020        -9.1       115.5
# Germany            Advanced       April           2020        -5.5        68.6
# India              Emerging       April           2020        -7.5        74.4
# Indonesia          Emerging       April           2020        -5.0        36.9
# Iran               Emerging       April           2020         0.0         0.0
# ...

# %%
data_2020.drop(index=['Argentina', 'Egypt', 'Iran', 'Kazakhstan', 'Malaysia', 'Netherlands',
                      'Pakistan', 'Philippines', 'Poland', 'Thailand'], inplace=True)
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.scatterplot(x='fiscal_bal', y='gross_debt', hue='projections',
                      style='economy_type', data=data_2020)
ax.set(ylabel='Gross debt (% of GDP)', xlabel='Fiscal balance (% of GDP)', 
       xlim=(-25, 0), ylim=(0, 300))
ax.legend()
plt.show()

# %%
data_2020[data_2020.projections=='April'].mean()
# Out:
# forecast_date    2020.00
# fiscal_bal         -8.43
# gross_debt         84.33
# dtype: float64

# %%
data_2020[data_2020.projections=='April'].std()
# Out:
# forecast_date     0.000000
# fiscal_bal        3.354981
# gross_debt       53.864031
# dtype: float64

# %%
data_2020[data_2020.projections=='April'].describe()
# Out:
#        forecast_date  fiscal_bal  gross_debt
# count           20.0   20.000000   20.000000
# mean          2020.0   -8.430000   84.330000
# std              0.0    3.354981   53.864031
# min           2020.0  -15.400000   17.900000
# 25%           2020.0  -10.075000   44.550000
# 50%           2020.0   -8.300000   71.500000
# 75%           2020.0   -6.175000  110.550000
# max           2020.0   -1.900000  252.000000

# %%
data_2020[data_2020.projections=='June'].mean()
# Out:
# forecast_date    2020.000
# fiscal_bal        -11.340
# gross_debt         89.195
# dtype: float64

# %%
data_2020[data_2020.projections=='April'].max()
# Out:
# economy_type     Emerging
# projections         April
# forecast_date        2020
# fiscal_bal           -1.9
# gross_debt            252
# dtype: object

# %%
data_2020[data_2020.projections=='April'].min()
# Out:
# economy_type     Advanced
# projections         April
# forecast_date        2020
# fiscal_bal          -15.4
# gross_debt           17.9
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.scatterplot(x='fiscal_bal', y='gross_debt', hue='projections',
                      style='economy_type', data=data_2020)
ax.set(ylabel='Gross debt (% of GDP)', xlabel='Fiscal balance (% of GDP)', 
       xlim=(-25, 0), ylim=(0, 300))
# ax.axhline(y=56.22, xmin=0, linestyle='--', color='b')
# ax.axvline(x=-5.62, linestyle='--', color='b')
# ax.axhline(y=89.195, linestyle='--', color='r')
# ax.axvline(x=-11.34, ymin=0, ymax=252, linestyle='--', color='r')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.scatterplot(x='fiscal_bal', y='gross_debt', hue='projections',
                     style='economy_type', data=data_2020, 
                     palette=['blue', 'red'],
                     s=100)
ax.set(ylabel='Gross debt (% of GDP)', xlabel='Fiscal balance (% of GDP)', 
       xlim=(-25, 0), ylim=(0, 300))
# ax.axhline(y=56.22, xmin=0, linestyle='--', color='b')
# ax.axvline(x=-5.62, linestyle='--', color='b')
# ax.axhline(y=89.195, linestyle='--', color='r')
# ax.axvline(x=-11.34, ymin=0, ymax=252, linestyle='--', color='r')
ax.legend()
plt.show()

# %%
from matplotlib.patches import Rectangle
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.scatterplot(x='fiscal_bal', y='gross_debt', hue='projections',
                     data=data_2020, palette=['blue', 'red'],
                     s=100)
ax.set(ylabel='Gross debt (% of GDP)', xlabel='Fiscal balance (% of GDP)', 
       xlim=(-25, 0), ylim=(0, 300))
ax.add_patch(Rectangle((-1, 10), -11, 185, 
                        fc ='None', ec ='b', lw = 2, ls='--'))
ax.add_patch(Rectangle((-12, 60), -12.5, 210, 
                        fc ='None', ec ='r', lw = 2, ls='--'))

from matplotlib.lines import Line2D
custom = [Line2D([], [], marker='.', color='b', linestyle='None', markersize=15),
          Line2D([], [], marker='.', color='r', linestyle='None', markersize=15)]
plt.legend(custom, ['2020 Projections made in April', '2020 Projections made in June'], 
           ncol=2, loc='upper center')
fig.suptitle('The sharp contraction in output and protracted decline in revenues, \
along with aggressive fiscal support, \nhave led to budget deficits and public debt higher than previously forecast.') 
plt.annotate('Source: IMF World Economic Outlook database (accessed 13 July 2020).', 
             xy=(-0.09, -0.15), xycoords='axes fraction', textcoords='offset points', va='top')
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:21: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.

# %%
data_2020[data_2020.projections=='April'].describe()
# Out:
#        forecast_date  fiscal_bal  gross_debt
# count           20.0   20.000000   20.000000
# mean          2020.0   -8.430000   84.330000
# std              0.0    3.354981   53.864031
# min           2020.0  -15.400000   17.900000
# 25%           2020.0  -10.075000   44.550000
# 50%           2020.0   -8.300000   71.500000
# 75%           2020.0   -6.175000  110.550000
# max           2020.0   -1.900000  252.000000

# %%
data_2020[data_2020.projections=='June'].describe()
# Out:
#        forecast_date  fiscal_bal  gross_debt
# count           20.0   20.000000    20.00000
# mean          2020.0  -11.340000    89.19500
# std              0.0    4.583426    57.87847
# min           2020.0  -23.800000    18.50000
# 25%           2020.0  -13.675000    47.22500
# 50%           2020.0  -12.100000    78.55000
# 75%           2020.0   -8.125000   112.92500
# max           2020.0   -3.600000   268.00000

# %%
from matplotlib.patches import Rectangle
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.scatterplot(x='fiscal_bal', y='gross_debt', hue='projections',
                     data=data_2020, palette=['blue', 'red'],
                     s=100)
ax.set(ylabel='Gross debt (% of GDP)', xlabel='Fiscal balance (% of GDP)', 
       xlim=(-25, 0), ylim=(0, 300))
ax.add_patch(Rectangle((-1.5, 10), -14.2, 252, 
                        fc ='None', ec ='b', lw = 2, ls='--'))
ax.add_patch(Rectangle((-3, 15), -21, 260, 
                        fc ='None', ec ='r', lw = 2, ls='--'))

from matplotlib.lines import Line2D
custom = [Line2D([], [], marker='.', color='b', linestyle='None', markersize=10),
          Line2D([], [], marker='.', color='r', linestyle='None', markersize=10)]
plt.legend(custom, ['2020 projections made in April', '2020 projections made in June'], 
           ncol=2, loc='upper center')
fig.suptitle('Countries are providing sizable fiscal support through budgetary measures, \
as well as off-budget liquidity, \npushing fiscal deficits and debt higher than previously forecast.') 
plt.annotate('Source: IMF World Economic Outlook database (accessed 13 July 2020).', 
             xy=(-0.09, -0.15), xycoords='axes fraction', textcoords='offset points', va='top')
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:21: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.

# %%
data_2020
# Out:
#                economy_type projections  forecast_date  fiscal_bal  gross_debt
# Australia          Advanced       April           2020        -9.7        59.3
# Brazil             Emerging       April           2020        -9.4        98.2
# Canada             Advanced       April           2020       -11.8       109.6
# China              Emerging       April           2020       -11.2        64.9
# France             Advanced       April           2020        -9.1       115.5
# Germany            Advanced       April           2020        -5.5        68.6
# India              Emerging       April           2020        -7.5        74.4
# Indonesia          Emerging       April           2020        -5.0        36.9
# Italy              Advanced       April           2020        -8.3       155.5
# Japan              Advanced       April           2020        -7.1       252.0
# Korea              Advanced       April           2020        -1.9        46.3
# ...

# %%
from matplotlib.patches import Rectangle
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.scatterplot(x='fiscal_bal', y='gross_debt', hue='projections', style='economy_type',
                     data=data_2020, palette=['blue', 'red'],
                     s=100)
ax.set(ylabel='Gross debt (% of GDP)', xlabel='Fiscal balance (% of GDP)', 
       xlim=(-25, 0), ylim=(0, 300))
ax.add_patch(Rectangle((-1.5, 10), -14.2, 252, 
                        fc ='None', ec ='b', lw = 2, ls='--'))
ax.add_patch(Rectangle((-3, 15), -21, 260, 
                        fc ='None', ec ='r', lw = 2, ls='--'))

from matplotlib.lines import Line2D
custom = [Line2D([], [], marker='.', color='b', linestyle='None', markersize=10),
          Line2D([], [], marker='.', color='r', linestyle='None', markersize=10),
          Line2D([], [], marker='.', color='black', linestyle='None', markersize=10),
          Line2D([], [], marker='x', color='black', linestyle='None', markersize=10)]
plt.legend(custom, ['2020 projections made in April', '2020 projections made in June',
                    'Emerging economies', 'Advanced economies'], 
           ncol=1, loc='upper left', frameon=True)
fig.suptitle('Countries are providing sizable fiscal support through budgetary measures, \
as well as off-budget liquidity, \npushing fiscal deficits and debt higher than previously forecast.') 
plt.annotate('Source: IMF World Economic Outlook database (accessed 13 July 2020).', 
             xy=(-0.09, -0.15), xycoords='axes fraction', textcoords='offset points', va='top')
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:24: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.

# %%
country_iso = pd.Series({'Australia':'AUS', 'Brazil':'BRA', 'Canada':'CAN', 'China':'CHN',
                         'France':'FRA', 'Germany':'DEU', 'India':'IND', 'Indonesia':'INO',
                         'Italy':'ITA', 'Japan':'JPN', 'Korea':'KOR', 'Mexico':'MEX',
                         'Nigeria':'NGA', 'Russia':'RUS', 'Saudi Arabia':'SAU', 
                         'South Africa':'ZAF', 'Spain':'ESP', 'Turkey':'TUR', 
                         'United Kingdom':'GBR', 'United States':'USA'}, name='country_iso')

# %%
data_2020 = data_2020.join(country_iso)

# %%
data_2020
# Out:
#                economy_type projections  forecast_date  fiscal_bal  \
# Australia          Advanced       April           2020        -9.7
# Australia          Advanced        June           2020        -8.6
# Brazil             Emerging       April           2020        -9.4
# Brazil             Emerging        June           2020       -16.0
# Canada             Advanced       April           2020       -11.8
# Canada             Advanced        June           2020       -12.6
# China              Emerging       April           2020       -11.2
# China              Emerging        June           2020       -12.1
# France             Advanced       April           2020        -9.1
# France             Advanced        June           2020       -13.6
# Germany            Advanced       April           2020        -5.5
# Germany            Advanced        June           2020       -10.7
# India              Emerging       April           2020        -7.5
# ...

# %%
from matplotlib.patches import Rectangle
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.scatterplot(x='fiscal_bal', y='gross_debt', hue='projections',
                     data=data_2020, palette=['blue', 'red'],
                     s=100)
ax.set(ylabel='Gross debt (% of GDP)', xlabel='Fiscal balance (% of GDP)', 
       xlim=(-25, 0), ylim=(0, 300))
# ax.add_patch(Rectangle((-1, 10), -11, 185, 
#                         fc ='None', ec ='b', lw = 2, ls='--'))
# ax.add_patch(Rectangle((-12, 60), -12.5, 210, 
#                         fc ='None', ec ='r', lw = 2, ls='--'))

for line in range(0, data_2020.shape[0]):
     ax.text(data_2020.fiscal_bal[line]+0.03, data_2020.gross_debt[line], 
             data_2020.country_iso[line], horizontalalignment='left', 
             size='small', color='black')

from matplotlib.lines import Line2D
custom = [Line2D([], [], marker='.', color='b', linestyle='None', markersize=15),
          Line2D([], [], marker='.', color='r', linestyle='None', markersize=15)]
plt.legend(custom, ['2020 Projections made in April', '2020 Projections made in June'], 
           ncol=2, loc='upper center')
fig.suptitle('The sharp contraction in output and protracted decline in revenues, \
along with aggressive fiscal support, \nhave led to budget deficits and public debt higher than previously forecast.') 
plt.annotate('Source: IMF World Economic Outlook database (accessed 13 July 2020).', 
             xy=(-0.09, -0.15), xycoords='axes fraction', textcoords='offset points', va='top')
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:26: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
